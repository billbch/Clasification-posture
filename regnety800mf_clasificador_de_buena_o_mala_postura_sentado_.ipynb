# %% [markdown]
# <a href="https://colab.research.google.com/github/billbch/Clasification-posture/blob/main/regnety800mf_clasificador_de_buena_o_mala_postura_sentado_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir sitting_well
# !mkdir sitting_wrong

# %%
# %cd sitting_well
# !unzip sitting_well.zip
# %cd ..

# %cd sitting_wrong
# !unzip sitting_wrong.zip
# %cd ..

# %%
#borrar zips
# !rm -rf /content/sitting_well/sitting_well.zip
# !rm -rf /content/sitting_wrong/sitting_wrong.zip

# %%
#mostrar cantidad de im de c/u
# !ls /content/sitting_well | wc -l #103
# !ls /content/sitting_wrong | wc -l #259
# Out:
# 103
# 259

# %%
#ver imagenes
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure(figsize=(15,15))

carpeta = '/content/sitting_wrong'
imagenes = os.listdir(carpeta)
for i, nombreimg in enumerate(imagenes[:10]):
  plt.subplot(5,5,i+1)
  imagen = mpimg.imread(carpeta + '/' + nombreimg)
  plt.imshow(imagen)

# %%
#borrar zips
# !rm -rf /content/dataset

# %%
#crear crpeta dataset

# !mkdir dataset
# !mkdir dataset/sitting_well
# !mkdir dataset/sitting_wrong

# %%
#copiar imagenes originales a la carpeta dataset
#con misma cantidad
import shutil

carpeta_fuente = '/content/sitting_well'
carpeta_destino = '/content/dataset/sitting_well'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i<103:
    #copiar de fuente a destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
#copiar imagenes originales a la carpeta dataset
#con misma cantidad
import shutil

carpeta_fuente = '/content/sitting_wrong'
carpeta_destino = '/content/dataset/sitting_wrong'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i<103:
    #copiar de fuente a destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
#mostrar cantidad de im de c/u del nuevo datset
# !ls /content/dataset/sitting_well | wc -l #
# !ls /content/dataset/sitting_wrong | wc -l #
# Out:
# 103
# 103

# %%
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
#crear dataset generator

datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.25,
    height_shift_range=0.25,
    shear_range=15,
    zoom_range=[0.5,1.5],
    validation_split=0.2 #20% para pruebas
    )

data_gen_entrenamiento = datagen.flow_from_directory('/content/dataset',target_size=(224,224),
                                                     batch_size=32, shuffle=True, subset='training')

data_gen_pruebas = datagen.flow_from_directory('/content/dataset',target_size=(224,224),
                                                     batch_size=32, shuffle=True, subset='validation')
# Out:
# Found 166 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.

# %%
#imprimir 10 img del generador de entrenamiento
for image, etiqueta in data_gen_entrenamiento:
  for i in range(10):
    plt.subplot(2,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(image[i])
  break
plt.show()

# %%
import tensorflow as tf
import tensorflow_hub as hub

url = 'https://tfhub.dev/adityakane2001/regnety800mf_classification/1'
mobilenetv2 = hub.KerasLayer(url,input_shape=(224,224,3))

# %%
#congelar el modelo descargado
mobilenetv2.trainable = False

# %%
modelo = tf.keras.Sequential([
    mobilenetv2,
    tf.keras.layers.Dense(2,activation='softmax')
])

# %%
modelo.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer_1 (KerasLayer)  (None, 1000)              6501119
#
#  dense_1 (Dense)             (None, 2)                 2002
#
# =================================================================
# Total params: 6,503,121
# Trainable params: 2,002
# Non-trainable params: 6,501,119
# _________________________________________________________________

# %%
#compilar
modelo.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
    )

# %%
EPOCAS=50

historial = modelo.fit(data_gen_entrenamiento, epochs=EPOCAS,batch_size=32,
                       validation_data= data_gen_pruebas)
# Out:
# Epoch 1/50
# 6/6 [==============================] - 17s 757ms/step - loss: 1.4475 - accuracy: 0.5241 - val_loss: 0.7891 - val_accuracy: 0.5000
# Epoch 2/50
# 6/6 [==============================] - 3s 485ms/step - loss: 0.7601 - accuracy: 0.4880 - val_loss: 0.7741 - val_accuracy: 0.5000
# Epoch 3/50
# 6/6 [==============================] - 3s 484ms/step - loss: 0.7426 - accuracy: 0.4639 - val_loss: 0.6756 - val_accuracy: 0.7000
# Epoch 4/50
# 6/6 [==============================] - 3s 479ms/step - loss: 0.7206 - accuracy: 0.5301 - val_loss: 1.3568 - val_accuracy: 0.5000
# Epoch 5/50
# 6/6 [==============================] - 3s 562ms/step - loss: 1.3186 - accuracy: 0.5241 - val_loss: 1.0870 - val_accuracy: 0.5000
# Epoch 6/50
# 6/6 [==============================] - 3s 487ms/step - loss: 1.0784 - accuracy: 0.5060 - val_loss: 1.0198 - val_accuracy: 0.5000
# Epoch 7/50
# 6/6 [==============================] - 3s 492ms/step - loss: 1.1545 - accuracy: 0.5000 - val_loss: 1.3463 - val_accuracy: 0.5000
# Epoch 8/50
# 6/6 [==============================] - 3s 486ms/step - loss: 1.0351 - accuracy: 0.5301 - val_loss: 0.7265 - val_accuracy: 0.5000
# Epoch 9/50
# 6/6 [==============================] - 3s 490ms/step - loss: 0.9427 - accuracy: 0.4518 - val_loss: 1.1022 - val_accuracy: 0.5000
# Epoch 10/50
# 6/6 [==============================] - 3s 484ms/step - loss: 0.8866 - accuracy: 0.4699 - val_loss: 0.7921 - val_accuracy: 0.5000
# Epoch 11/50
# 6/6 [==============================] - 3s 484ms/step - loss: 0.9155 - accuracy: 0.5120 - val_loss: 0.7504 - val_accuracy: 0.5000
# Epoch 12/50
# 6/6 [==============================] - 3s 489ms/step - loss: 1.1764 - accuracy: 0.4036 - val_loss: 1.6709 - val_accuracy: 0.5000
# Epoch 13/50
# 6/6 [==============================] - 3s 482ms/step - loss: 1.3589 - accuracy: 0.5120 - val_loss: 1.3231 - val_accuracy: 0.5000
# Epoch 14/50
# 6/6 [==============================] - 3s 481ms/step - loss: 1.1541 - accuracy: 0.4518 - val_loss: 0.9062 - val_accuracy: 0.5000
# Epoch 15/50
# 6/6 [==============================] - 3s 552ms/step - loss: 1.1189 - accuracy: 0.4880 - val_loss: 1.2135 - val_accuracy: 0.5000
# Epoch 16/50
# 6/6 [==============================] - 3s 481ms/step - loss: 1.1800 - accuracy: 0.5000 - val_loss: 0.7212 - val_accuracy: 0.5000
# Epoch 17/50
# 6/6 [==============================] - 3s 489ms/step - loss: 1.1124 - accuracy: 0.4759 - val_loss: 1.0524 - val_accuracy: 0.5000
# Epoch 18/50
# 6/6 [==============================] - 3s 486ms/step - loss: 1.0930 - accuracy: 0.4880 - val_loss: 0.9639 - val_accuracy: 0.5000
# Epoch 19/50
# 6/6 [==============================] - 3s 553ms/step - loss: 0.8742 - accuracy: 0.4759 - val_loss: 0.7598 - val_accuracy: 0.5000
# Epoch 20/50
# 6/6 [==============================] - 3s 482ms/step - loss: 0.7979 - accuracy: 0.5181 - val_loss: 0.8297 - val_accuracy: 0.5000
# Epoch 21/50
# 6/6 [==============================] - 3s 494ms/step - loss: 0.7580 - accuracy: 0.5120 - val_loss: 0.6831 - val_accuracy: 0.5000
# Epoch 22/50
# 6/6 [==============================] - 3s 490ms/step - loss: 0.7144 - accuracy: 0.5000 - val_loss: 0.6855 - val_accuracy: 0.5500
# Epoch 23/50
# 6/6 [==============================] - 3s 488ms/step - loss: 0.7522 - accuracy: 0.5181 - val_loss: 0.9604 - val_accuracy: 0.5000
# Epoch 24/50
# 6/6 [==============================] - 3s 485ms/step - loss: 0.9439 - accuracy: 0.4277 - val_loss: 0.9662 - val_accuracy: 0.5000
# Epoch 25/50
# 6/6 [==============================] - 4s 685ms/step - loss: 0.9726 - accuracy: 0.4880 - val_loss: 0.7497 - val_accuracy: 0.5000
# Epoch 26/50
# 6/6 [==============================] - 3s 485ms/step - loss: 0.7955 - accuracy: 0.4639 - val_loss: 0.7594 - val_accuracy: 0.5000
# Epoch 27/50
# 6/6 [==============================] - 3s 476ms/step - loss: 0.7346 - accuracy: 0.5120 - val_loss: 0.6705 - val_accuracy: 0.6500
# Epoch 28/50
# 6/6 [==============================] - 3s 491ms/step - loss: 0.7142 - accuracy: 0.5482 - val_loss: 0.7233 - val_accuracy: 0.5000
# Epoch 29/50
# 6/6 [==============================] - 3s 482ms/step - loss: 0.7425 - accuracy: 0.4639 - val_loss: 0.7088 - val_accuracy: 0.5000
# Epoch 30/50
# 6/6 [==============================] - 3s 485ms/step - loss: 0.7384 - accuracy: 0.5482 - val_loss: 0.8309 - val_accuracy: 0.5000
# Epoch 31/50
# 6/6 [==============================] - 3s 491ms/step - loss: 1.1049 - accuracy: 0.4578 - val_loss: 0.9063 - val_accuracy: 0.5000
# Epoch 32/50
# 6/6 [==============================] - 3s 475ms/step - loss: 1.0272 - accuracy: 0.5120 - val_loss: 1.1070 - val_accuracy: 0.5000
# Epoch 33/50
# 6/6 [==============================] - 3s 486ms/step - loss: 1.2845 - accuracy: 0.5120 - val_loss: 0.8037 - val_accuracy: 0.5000
# Epoch 34/50
# 6/6 [==============================] - 3s 494ms/step - loss: 0.9179 - accuracy: 0.5241 - val_loss: 1.0787 - val_accuracy: 0.5000
# Epoch 35/50
# 6/6 [==============================] - 3s 485ms/step - loss: 1.0012 - accuracy: 0.4639 - val_loss: 0.6925 - val_accuracy: 0.5500
# Epoch 36/50
# 6/6 [==============================] - 3s 496ms/step - loss: 0.7140 - accuracy: 0.5181 - val_loss: 0.6983 - val_accuracy: 0.5000
# Epoch 37/50
# 6/6 [==============================] - 3s 487ms/step - loss: 0.7131 - accuracy: 0.4940 - val_loss: 0.6998 - val_accuracy: 0.5000
# Epoch 38/50
# 6/6 [==============================] - 3s 556ms/step - loss: 0.7593 - accuracy: 0.5120 - val_loss: 0.7321 - val_accuracy: 0.5000
# Epoch 39/50
# 6/6 [==============================] - 3s 480ms/step - loss: 0.8355 - accuracy: 0.4819 - val_loss: 0.8857 - val_accuracy: 0.5000
# Epoch 40/50
# 6/6 [==============================] - 3s 484ms/step - loss: 0.8172 - accuracy: 0.4699 - val_loss: 0.7920 - val_accuracy: 0.5000
# Epoch 41/50
# 6/6 [==============================] - 3s 485ms/step - loss: 0.9367 - accuracy: 0.4277 - val_loss: 0.7321 - val_accuracy: 0.5000
# Epoch 42/50
# 6/6 [==============================] - 3s 492ms/step - loss: 0.8641 - accuracy: 0.4699 - val_loss: 0.6827 - val_accuracy: 0.5750
# Epoch 43/50
# 6/6 [==============================] - 3s 565ms/step - loss: 0.7486 - accuracy: 0.4518 - val_loss: 0.6904 - val_accuracy: 0.5250
# Epoch 44/50
# 6/6 [==============================] - 3s 481ms/step - loss: 0.7321 - accuracy: 0.4036 - val_loss: 0.6864 - val_accuracy: 0.5000
# Epoch 45/50
# 6/6 [==============================] - 3s 479ms/step - loss: 0.7552 - accuracy: 0.4759 - val_loss: 0.6874 - val_accuracy: 0.5750
# Epoch 46/50
# 6/6 [==============================] - 3s 482ms/step - loss: 0.7800 - accuracy: 0.4819 - val_loss: 0.7239 - val_accuracy: 0.5000
# Epoch 47/50
# 6/6 [==============================] - 3s 477ms/step - loss: 0.7721 - accuracy: 0.4819 - val_loss: 1.0800 - val_accuracy: 0.5000
# Epoch 48/50
# 6/6 [==============================] - 3s 476ms/step - loss: 1.0919 - accuracy: 0.4277 - val_loss: 0.7816 - val_accuracy: 0.5000
# Epoch 49/50
# 6/6 [==============================] - 3s 479ms/step - loss: 0.9016 - accuracy: 0.4759 - val_loss: 0.7478 - val_accuracy: 0.5000
# Epoch 50/50
# 6/6 [==============================] - 3s 476ms/step - loss: 0.8404 - accuracy: 0.4759 - val_loss: 1.0044 - val_accuracy: 0.5000

# %%
#Gracias
acc = historial.history['accuracy']
val_acc = historial.history['val_accuracy']

loss = historial.history['loss']
val_loss = historial.history['val_loss']

rango_epocas = range(50)

plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plt.plot(rango_epocas, acc, label='Presicion Entrenamiento')
plt.plot(rango_epocas, val_acc,label='Presicion Pruebas')
plt.legend(loc='lower right')
plt.title('Presicion de entrenamiento y pruebas')
plt.show()

plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
plt.plot(rango_epocas, loss, label='Perdida de Entrenamiento')
plt.plot(rango_epocas, val_loss,label='Perdida de Pruebas')
plt.legend(loc='lower right')
plt.title('Presicion de entrenamiento y pruebas')
plt.show()

# %%
from PIL import Image
import requests
from io import BytesIO
import cv2

def categorizar(url):
  respuesta = requests.get(url)
  img = Image.open(BytesIO(respuesta.content))
  img = np.array(img).astype(float)/255

  img = cv2.resize(img, (224,224))
  prediccion = modelo.predict(img.reshape(-1,224,224,3))
  return np.argmax(prediccion[0],axis=-1)

# %%
#0 = bien #1 = mal
url='https://www.dornacoluna.fst.br/site/imagem/-sentar_corretamente_com_o_rolo_lombar_mckenzie_2.jpg'
prediccion = categorizar(url)
print(prediccion)
# Out:
# 1/1 [==============================] - 1s 1s/step
# 1
